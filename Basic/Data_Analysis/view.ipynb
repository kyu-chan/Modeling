# %%
import matplotlib.pyplot as plt
import sys
import os
import matplotlib as pt
pt.use("Qt5Agg")
sys.path.append(r'C:\Users\pc\Desktop\stock\Modeling\Basic\wrapper')

from wrapper import data_pred
from wrapper import common
from wrapper import visualization
import wrapper as fs

#print(dir())   ####절대경로로 돌려서 불러오고 임포트된거 확인
os.chdir(r'C:\Users\pc\Desktop\stock\Modeling\Basic')
cd ='S&P 500'
path = 'C:/Users/pc/Desktop/stock/Modeling/Basic/data/'
ld = data_pred.LoadData()
df = ld.read_investing_price(path, cd)

## 날짜 처리
df1 = ld.date_formatting(df)

### price 숫자로 처리
df2 = ld.price_formatting(df1)
print(df2['Price'])
print(df2['Price'][2]+df2['Price'][3])  ### 숫자로 변환 굿

### portfolio
portfolio = {
    'World indices' : ['Kospi 200', 'S&P 500', 'Nikkei 225', 'CSI 300']
}   ## 딕셔너리 형태
p_name = 'World indices'
p_cd = portfolio[p_name]
p_df = ld.create_portfolio_df(path, p_name, p_cd)
print(p_df.tail())


### 시각화

v = visualization.Visualize()
base_date = '2017-03-05'
v.index_view(p_df, base_date, p_cd)
# Out:
# Date
# 2019-06-07   2,873.34
# 2019-06-06   2,843.49
# 2019-06-05   2,826.15
# 2019-06-04   2,803.27
# 2019-06-03   2,744.45
#                ...
# 2017-01-09   2,268.90
# 2017-01-06   2,276.98
# 2017-01-05   2,269.00
# 2017-01-04   2,270.75
# 2017-01-03   2,257.83
# Name: Price, Length: 611, dtype: float64
# 5629.42
# Kospi 200 593
# S&P 500 611
# Nikkei 225 596
# CSI 300 590
# Updating master file
#             CSI 300  KOSPI 200  Kospi 200  Nikkei 225  S&P 500
# Date
# 2019-06-03 3,632.01     268.16     268.16   20,410.88 2,744.45
# 2019-06-04 3,598.47     267.66     267.66   20,408.54 2,803.27
# 2019-06-05 3,597.11     267.99     267.99   20,776.10 2,826.15
# 2019-06-06 3,564.68     267.99     267.99   20,774.04 2,843.49
# 2019-06-07 3,564.68     268.27     268.27   20,884.71 2,873.34

# %%
import matplotlib.pyplot as plt

v = visualization.Visualize()
base_date = '2017-03-05'
v.index_view(p_df, base_date, p_cd)
